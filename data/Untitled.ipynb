# %%
import pandas as pd

# %%
ar_book = pd.read_csv('arabic_book_reviews.csv')
ar_book.head()
# Out:
#    Unnamed: 0                                     English review
# 0           0  A wonderful book. I think that the whole novel...
# 1           1  Novel touches the soul Bamgaha, proud that I f...
# 2           2  A novel court every shortcut. It was my favori...
# 3           3  This book is sad bitter, injustice and persecu...
# 4           4  Novel and represent a realistic and fantastic ...

# %%
ar_hotel = pd.read_csv('arabic_hotel_reviews.csv')
ar_hotel.head()
# Out:
#    no Hotel name  rating    user type                   room type  \
# 0   1    فندق 72       4          زوج          غرفة قياسية مزدوجة
# 1   2    فندق 72       2  مسافر منفرد  غرفة ديلوكس مزدوجة أو توأم
# 2   3    فندق 72       5          زوج  غرفة ديلوكس مزدوجة أو توأم
# 3   4    فندق 72       4          زوج          غرفة قياسية مزدوجة
# 4   5    فندق 72       5          زوج  غرفة ديلوكس مزدوجة أو توأم
#
#             nights                                             review  \
# 0  أقمت ليلة واحدة  “فندق راقي وسوف تتكرر زيارتي له”. الفندق بصراح...
# 1  أقمت ليلة واحدة                  “ممتاز”. النظافة والطاقم متعاون.
# 2  أقمت ليلة واحدة  استثنائي. سهولة إنهاء المعاملة في الاستقبال. ل...
# 3  أقمت ليلة واحدة                               جيد جداً. 😊👍. لايوجد
# 4  أقمت ليلة واحدة  “الحمدلله رب العالمين كان يوم جميل قضيناه في ا...
#
#                                             enreview
# 0  Sophisticated hotel and will be repeated my vi...
# ...

# %%
ar_hotel_rev = ar_hotel['enreview']

# %%
ar_hotel_rev.to_csv('arabic_hotel_reviews.csv')

# %%
ar_hotel_rev.head()
# Out:
# 0    Sophisticated hotel and will be repeated my vi...
# 1          Excellent cleanliness and crew collaborator
# 2    Exceptionally easy treatment to end the recept...
# 3                                       Very good does
# 4    Praise be to Allah, Lord of the Worlds beautif...
# Name: enreview, dtype: object

# %%
en_hotel = pd.read_csv('english_hotel_reviews.csv')
en_hotel.head()
# Out:
#                                        Hotel_Address  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
#
#    Additional_Number_of_Scoring Review_Date  Average_Score   Hotel_Name  \
# 0                           194    8/3/2017            7.7  Hotel Arena
# 1                           194    8/3/2017            7.7  Hotel Arena
# 2                           194   7/31/2017            7.7  Hotel Arena
# 3                           194   7/31/2017            7.7  Hotel Arena
# 4                           194   7/24/2017            7.7  Hotel Arena
#
#   Reviewer_Nationality                                    Negative_Review  \
# 0              Russia    I am so angry that i made this post available...
# ...

# %%
eng_pos = en_hotel['Positive_Review']
eng_neg = en_hotel['Negative_Review']

# %%
eng_pos.to_csv('english_pos_hotel_reviews.csv')
eng_neg.to_csv('english_neg_hotel_reviews.csv')

# %%
english_data = next(pd.read_json('english_reviews.json',lines=True,chunksize=80000))
english_sents = english_data['review_text']

# %%
english_sents.to_csv('english_books_reviews.csv')
